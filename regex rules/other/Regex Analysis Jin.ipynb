# %%
# python 3
import pandas as pd
import nltk
import re

from nltk.corpus import stopwords
from nltk import ngrams

pd.set_option('display.max_colwidth', -1)
pd.set_option("display.max_rows",3000)

# %%
# get majority labels and all labels

def clean_label(df_agent1, df_agent2, df_agent3):
    label_column = df_agent1.filter(regex='Label').columns
    label1, label2, label3, label4, label5 = label_column[0], \
                                             label_column[1], \
                                             label_column[2], \
                                             label_column[3], \
                                             label_column[4]
    
    df_agent1[label_column] = df_agent1[label_column].fillna('null_value')
    df_agent2[label_column] = df_agent2[label_column].fillna('null_value')
    df_agent3[label_column] = df_agent3[label_column].fillna('null_value')
    
    df_agent1['agent1_labels'] = df_agent1.apply(lambda x: set([x[label1],
                                 x[label2],
                                 x[label3],
                                 x[label4],                         
                                 x[label5]]),axis=1)
    
    df_agent1['agent2_labels'] = df_agent2.apply(lambda x: set([x[label1],
                                 x[label2],
                                 x[label3],
                                 x[label4],                         
                                 x[label5]]),axis=1)
    
    df_agent1['agent3_labels'] = df_agent3.apply(lambda x: set([x[label1],
                                 x[label2],
                                 x[label3],
                                 x[label4],                         
                                 x[label5]]),axis=1)
    
    df_agent1['majority_vote'] = df_agent1.apply(lambda x: x['agent1_labels'].intersection(x['agent2_labels'])\
                                         .union(x['agent2_labels'].intersection(x['agent3_labels']))\
                                         .union(x['agent1_labels'].intersection(x['agent3_labels']))\
                               , axis=1)
    
    df_agent1['union_vote'] = df_agent1.apply(lambda x: x['agent1_labels'].union(x['agent2_labels'])\
                                         .union(x['agent3_labels'])\
                               , axis=1)
    
    # trick to associate new variable with column method operations
    mv = df_agent1['majority_vote']
    mv.apply(lambda x: x.discard('null_value'));
    
    uv = df_agent1['union_vote']
    uv.apply(lambda x: x.discard('null_value'));
    return df_agent1.drop(label_column, axis=1)

# %%
# get data

one_ic = pd.read_csv('data/1-ic.csv')
one_gc = pd.read_csv('data/1-gc.csv')
one_sc = pd.read_csv('data/1-sc.csv')

two_jm = pd.read_csv('data/2-jm.csv')
two_mg = pd.read_csv('data/2-mg.csv')
two_nb = pd.read_csv('data/2-nb.csv')

three_rs = pd.read_csv('data/3-rs.csv')
three_rt = pd.read_csv('data/3-rt.csv')
three_sj = pd.read_csv('data/3-sj.csv')

tph_batch1 = pd.read_csv('data/tph_batch1.csv')

# %%
tph_batch1.rename({'sampled_bid_id': 'bid_id'}, axis='columns', inplace=True)

# %%
# clean labels

df1 = clean_label(one_ic, one_gc, one_sc)
df2 = clean_label(two_jm, two_mg, two_nb)
df3 = clean_label(three_rs, three_rt, three_sj)

# %%
# merge data

df = df1.append(df2).append(df3)

# %%
df = df.merge(tph_batch1[['bid_id','message_timestamp','message']], \
              how='left', on = ['bid_id','message_timestamp'])

# %%
#df['is_hire_majority'] = df.apply(lambda x: ('Hire' in x['majority_vote'])*1, axis=1)
#df['is_hire_any'] = df.apply(lambda x: ('Hire' in x['union_vote'])*1, axis=1)

# %%
df['is_contact_info'] = df.apply(lambda x: ('Contact Information' in x['majority_vote'])*1, axis=1)
df['is_scheduling'] = df.apply(lambda x: ('Scheduling - Meeting or Job' in x['majority_vote'])*1, axis=1)
df['is_price'] = df.apply(lambda x: ('Price' in x['majority_vote'])*1, axis=1)
df['is_payment'] = df.apply(lambda x: ('Payment' in x['majority_vote'])*1, axis=1)
df['is_generic'] = df.apply(lambda x: ('Generic Answer' in x['majority_vote'])*1, axis=1)

# %%
# helper function to dislay frequency of words from a blob of text 
def get_info(txt):
    words = nltk.tokenize.word_tokenize(txt)

    bigrams = nltk.bigrams(words)
    trigrams = nltk.trigrams(words)

    word_dist = nltk.FreqDist(words)
    top_N = 200
    custom_stopwords = set((u'.', u',', u'?', u'!', u')', u':', u'\'s', u'('))

    words_except_stop_dist = nltk.FreqDist(w for w in words if w not in custom_stopwords) 

    print('Unigram frequencies:')
    rslt = pd.DataFrame(words_except_stop_dist.most_common(top_N),
                        columns=['Word', 'Frequency']).set_index('Word')
    print(rslt)
    print('=' * 60)

    # Bigram Frequencies
    print('Bigram frequencies:')
    bigrams_freq = nltk.FreqDist(bigrams)
    rslt = pd.DataFrame(bigrams_freq.most_common(top_N),
                        columns=['Word', 'Frequency']).set_index('Word')

    print(rslt)
    print('=' * 60)

    # Trigram Frequencies
    print('Trigram frequencies:')
    trigrams_freq = nltk.FreqDist(trigrams)
    rslt = pd.DataFrame(trigrams_freq.most_common(top_N),
                        columns=['Word', 'Frequency']).set_index('Word')

    print(rslt)
    print('=' * 60)

# %%
# helper function to dislay precision and recall information from a term and a specific column we evaluate against 

def display_info(term, col):
    pat1 = re.compile("^.*"+term+".*$" , flags = re.DOTALL) # equivalent to str.contains # re.DOTALL applies REGEX to muliple line
    predicted = df['message'].str.lower().str.match(pat1).astype(int)
    precision = df.loc[predicted[predicted==1].index, col].sum()/\
            df.loc[predicted[predicted==1].index, col].count()

    recall = df.loc[predicted[predicted==1].index, col].sum()/\
            df[col].sum()    
        
    false_positive_cases = df.loc[(df['message'].str.lower().str.match(pat1)) \
                              & (df.is_scheduling == 0)]['message']
    
    num_terms = df.loc[predicted[predicted==1].index, col].sum()
    return [term, 
            "{0:.0f}%".format(precision*100), 
            "{0:.0f}%".format(recall*100), 
            num_terms]

# %%
# helper function to dislay precision and recall information from a group of terms and a specific column we evaluate against 

def display_info_multiple(key_words, col):
    regex_pattern = "^.*("
    for i,w in enumerate(key_words):
        if i != len(key_words) -1:
            regex_pattern += w +'|'
        else:
            regex_pattern += w 

    regex_pattern += ").*$"
    
    pat1 = re.compile(regex_pattern , flags = re.DOTALL) # equivalent to str.contains
    predicted = df['message'].str.lower().str.match(pat1).astype(int)
    precision = df.loc[predicted[predicted==1].index, col].sum()/\
            df.loc[predicted[predicted==1].index, col].count()

    recall = df.loc[predicted[predicted==1].index, col].sum()/\
            df[col].sum()    
        
    false_positive_cases = df.loc[(df['message'].str.lower().str.match(pat1)) \
                              & (df.is_scheduling == 0)]['message']
    
    num_terms = df.loc[predicted[predicted==1].index, col].sum()
    return [regex_pattern, 
            "{0:.0f}%".format(precision*100), 
            "{0:.0f}%".format(recall*100), 
            num_terms
           ]

# %%
# test function
display_info('available', 'is_scheduling')
# Out:
# ['available', '91%', '13%', 671]

# %%
# test function
display_info_multiple(['available','weekday'], 'is_scheduling')
# Out:
# ['^.*(available|weekday).*$', '91%', '13%', 693]

# %% [markdown]
# ## Scheduling

# %%
df[(df.is_scheduling==1) & (df.is_generic == 1)].shape
# Out:
# (88, 18)

# %%
df[(df.is_scheduling==1)].shape
# Out:
# (5182, 18)

# %%
get_info(df[df.is_scheduling == 1].message.str.lower().str.cat(sep=' '))
# Out:
# Unigram frequencies:
#               Frequency
# Word
# you           5457
# i             5224
# to            3996
# the           3374
# and           2593
# a             2449
# for           2435
# can           1780
# we            1682
# is            1577
# be            1528
# have          1386
# me            1352
# if            1307
# at            1283
# that          1248
# in            1234
# would         1232
# will          1209
# on            1187
# your          1172
# do            1171
# it            990
# my            989
# are           980
# time          977
# of            942
# or            905
# this          861
# tomorrow      853
# with          776
# hi            760
# so            740
# work          729
# available     712
# am            702
# call          693
# what          691
# know          686
# let           662
# thanks        619
# like          579
# 'm            554
# just          537
# as            526
# thank         523
# but           510
# get           503
# good          503
# come          487
# morning       477
# when          474
# today         450
# there         441
# up            437
# need          433
# week          427
# n't           424
# schedule      422
# day           413
# out           412
# please        408
# not           402
# yes           394
# an            392
# about         388
# give          385
# could         370
# friday        364
# any           362
# 'll           355
# our           350
# see           345
# next          344
# by            335
# after         321
# address       320
# ok            314
# monday        311
# works         310
# all           301
# great         298
# from          293
# around        292
# how           282
# meet          271
# phone         267
# also          267
# back          265
# still         262
# free          260
# sorry         259
# saturday      249
# afternoon     248
# look          243
# best          243
# number        237
# -             236
# us            236
# want          235
# now           226
# thursday      220
# make          218
# $             213
# then          211
# send          209
# hello         200
# home          198
# set           197
# ...           197
# looking       195
# quote         192
# take          186
# tuesday       185
# some          184
# no            182
# able          181
# pm            180
# before        179
# talk          177
# evening       177
# go            176
# between       173
# appointment   170
# was           169
# wednesday     169
# sure          168
# sounds        168
# forward       167
# estimate      166
# may           163
# more          161
# email         156
# well          155
# start         155
# date          154
# does          152
# over          151
# one           150
# july          149
# 're           144
# until         143
# done          141
# 2             141
# much          141
# weekend       141
# 'd            139
# &             138
# anytime       137
# should        135
# soon          131
# availability  130
# fine          130
# days          128
# text          127
# here          126
# 10            123
# sunday        123
# way           122
# did           122
# questions     121
# hey           119
# they          119
# think         118
# other         118
# interested    117
# love          117
# only          116
# check         116
# house         113
# again         112
# wanted        112
# going         112
# open          111
# very          111
# job           111
# right         110
# meeting       108
# wedding       108
# 3             107
# 5             107
# he            106
# possible      105
# them          105
# times         105
# okay          104
# u             104
# problem       103
# later         102
# @             101
# help          101
# early         101
# discuss       100
# her           100
# first         99
# move          99
# contact       97
# price         95
# 4             95
# better        94
# ============================================================
# Bigram frequencies:
#                      Frequency
# Word
# (., i)               1341
# (i, can)             628
# (if, you)            601
# (,, i)               584
# (for, you)           554
# (i, 'm)              553
# (thank, you)         516
# (i, will)            500
# (i, am)              499
# (let, me)            465
# (me, know)           432
# (?, i)               421
# (i, have)            400
# (will, be)           370
# (we, can)            346
# (you, .)             343
# (like, to)           335
# (in, the)            318
# (., we)              317
# (you, have)          309
# (would, be)          299
# (., thanks)          297
# (are, you)           292
# (i, 'll)             288
# (have, a)            283
# (do, you)            281
# (and, i)             268
# (for, the)           260
# (you, can)           251
# (!, i)               250
# (you, ?)             237
# (with, you)          237
# (i, would)           236
# (we, are)            236
# (,, and)             227
# (a, call)            224
# (on, the)            222
# (., thank)           220
# (would, you)         218
# (would, like)        214
# (., if)              206
# (you, a)             201
# (what, time)         197
# (of, the)            193
# (give, you)          190
# (to, come)           188
# (work, for)          186
# (able, to)           178
# (to, be)             175
# (., hi)              175
# (for, a)             174
# (can, you)           173
# (you, are)           173
# (to, get)            172
# (i, do)              169
# (to, you)            168
# (., my)              166
# (., the)             166
# (for, your)          162
# (you, for)           162
# (., let)             161
# (need, to)           161
# (but, i)             158
# (do, n't)            157
# (,, but)             157
# (?, yes)             156
# (next, week)         156
# (?, hi)              154
# (want, to)           154
# (., what)            153
# (can, do)            152
# (so, i)              150
# (if, that)           148
# (works, for)         147
# (,, we)              144
# (know, if)           144
# (see, you)           141
# (to, do)             141
# (., please)          140
# (it, 's)             140
# (forward, to)        140
# (this, week)         139
# (you, !)             139
# (you, like)          137
# (you, available)     136
# (for, me)            136
# (be, there)          134
# (set, up)            132
# (at, the)            129
# (call, me)           128
# (be, able)           128
# (a, good)            127
# (to, schedule)       126
# (and, we)            126
# (you, would)         126
# (., can)             125
# (i, just)            125
# (give, me)           124
# (time, to)           123
# (we, have)           122
# (to, meet)           121
# (we, will)           121
# (can, we)            121
# (please, let)        120
# (a, time)            120
# (have, to)           118
# (you, ,)             118
# (i, could)           118
# (., would)           117
# (that, 's)           117
# (tomorrow, .)        116
# (call, you)          114
# (phone, number)      113
# (when, you)          113
# (you, to)            113
# (as, well)           110
# (yes, ,)             109
# (., do)              108
# (be, available)      107
# (me, a)              106
# (thanks, !)          105
# (you, be)            105
# (that, works)        104
# (have, any)          104
# (you, and)           103
# (can, i)             103
# (wanted, to)         103
# (today, .)           103
# ('ll, be)            103
# (is, the)            102
# (you, want)          101
# (thanks, for)        100
# (., it)              98
# (week, .)            97
# (love, to)           97
# (i, need)            94
# (is, a)              93
# (come, out)          93
# (me, .)              93
# (you, 're)           93
# (schedule, a)        93
# (to, have)           92
# (look, at)           92
# (can, be)            92
# (can, come)          91
# (the, morning)       90
# (time, .)            90
# (know, what)         90
# (., you)             90
# (am, available)      88
# (to, see)            88
# (thanks, ,)          88
# (to, make)           87
# (sounds, good)       87
# (good, morning)      86
# (back, to)           86
# (we, would)          86
# (., are)             86
# (?, we)              86
# (up, a)              86
# (., when)            85
# (do, it)             85
# (you, know)          85
# (!, !)               85
# (tomorrow, morning)  85
# (:, ))               84
# (you, tomorrow)      83
# (look, forward)      83
# (address, and)       83
# (that, would)        83
# (free, to)           82
# ('d, like)           82
# (,, so)              82
# (if, i)              81
# (?, if)              81
# (to, talk)           80
# (what, is)           80
# (to, the)            80
# (so, much)           79
# (would, love)        79
# (work, ?)            79
# (we, do)             79
# (to, call)           78
# (me, to)             78
# (the, address)       78
# (tomorrow, at)       77
# (from, you)          77
# (is, there)          77
# (best, for)          77
# (you, come)          76
# (how, about)         76
# (yes, i)             75
# (with, the)          75
# (going, to)          75
# (when, can)          75
# (you, on)            74
# (address, is)        74
# (let, you)           74
# (great, .)           74
# (this, is)           73
# ============================================================
# Trigram frequencies:
#                         Frequency
# Word
# (let, me, know)         424
# (., thank, you)         217
# (for, you, ?)           188
# (., i, 'm)              159
# (would, like, to)       153
# (., i, will)            144
# (give, you, a)          144
# (work, for, you)        141
# (are, you, available)   134
# (i, will, be)           134
# (., let, me)            132
# (., i, am)              132
# (be, able, to)          127
# (do, you, have)         125
# (me, know, if)          122
# (thank, you, for)       121
# (for, you, .)           119
# (., if, you)            116
# (please, let, me)       112
# (., i, can)             111
# (works, for, you)       106
# (you, a, call)          105
# (would, you, like)      104
# (., i, have)            99
# (give, me, a)           91
# (i, have, a)            91
# (., do, you)            90
# (i, can, do)            88
# (you, would, like)      88
# (you, have, any)        87
# (you, like, to)         84
# (look, forward, to)     83
# (if, you, would)        82
# (i, am, available)      81
# (if, you, have)         81
# (i, 'll, be)            80
# (in, the, morning)      79
# (thank, you, !)         79
# (i, do, n't)            78
# (would, love, to)       77
# (., i, 'll)             77
# (,, i, 'm)              75
# (if, you, are)          74
# (me, know, what)        74
# (., are, you)           73
# (,, i, am)              72
# (thank, you, ,)         72
# (set, up, a)            72
# (and, i, will)          69
# (i, would, like)        69
# (feel, free, to)        69
# (., i, would)           68
# (you, ., i)             68
# (know, if, you)         68
# (would, you, be)        68
# (me, a, call)           67
# (thank, you, .)         67
# (let, you, know)        65
# (., would, you)         63
# (if, that, works)       63
# (and, we, can)          62
# (,, thank, you)         62
# ('d, like, to)          62
# (?, i, 'm)              62
# (., thanks, !)          60
# (a, good, time)         60
# (?, i, can)             59
# (back, to, you)         59
# (., we, are)            58
# (take, a, look)         57
# (., i, do)              57
# (to, set, up)           57
# (that, would, be)       57
# (looking, forward, to)  57
# (best, for, you)        57
# (., please, let)        56
# (that, works, for)      56
# (., can, you)           55
# (so, i, can)            55
# (would, be, great)      54
# (i, would, love)        53
# (?, i, am)              53
# (you, want, to)         52
# (like, to, schedule)    51
# (., what, time)         51
# (me, know, when)        51
# (to, come, out)         51
# (with, you, .)          50
# (a, call, ?)            50
# (i, look, forward)      50
# (to, schedule, a)       50
# (i, 'm, available)      50
# (just, let, me)         50
# (get, back, to)         49
# (., we, can)            49
# (you, for, your)        49
# (i, give, you)          49
# (just, wanted, to)      49
# (as, well, .)           48
# (?, thank, you)         48
# (can, you, come)        48
# (,, i, will)            48
# (as, soon, as)          48
# (., can, we)            47
# (if, you, can)          47
# (i, can, be)            47
# (i, need, to)           46
# (for, you, to)          46
# (., thanks, ,)          45
# (i, 'm, sorry)          45
# (?, i, have)            45
# (can, i, give)          45
# (., you, can)           45
# (i, can, come)          45
# (,, i, have)            45
# (!, thank, you)         44
# (you, ?, i)             44
# (for, me, .)            44
# (you, have, a)          43
# (you, 'd, like)         43
# (when, can, i)          43
# (., thanks, .)          43
# (,, i, can)             43
# (send, me, your)        42
# (you, be, available)    42
# (,, but, i)             42
# (,, thanks, for)        41
# (., we, have)           41
# (thank, you, so)        40
# (you, so, much)         40
# (?, yes, ,)             40
# (are, you, still)       39
# (we, will, be)          39
# (sounds, good, .)       39
# (is, there, a)          39
# (me, know, .)           38
# (call, me, at)          38
# (have, any, questions)  38
# (will, be, there)       38
# (to, give, you)         37
# (will, call, you)       37
# (to, you, .)            37
# (you, can, call)        37
# (,, i, would)           37
# (know, when, you)       37
# (,, i, 'll)             37
# (next, week, .)         37
# (to, see, if)           37
# (and, i, can)           36
# (so, we, can)           36
# (if, you, could)        36
# (that, work, for)       36
# (have, a, great)        36
# (will, be, in)          36
# (forward, to, meeting)  35
# (you, be, able)         35
# (your, address, and)    35
# (and, i, 'll)           35
# (we, can, do)           35
# (time, for, you)        35
# (can, be, there)        35
# (i, ca, n't)            34
# (,, are, you)           34
# (if, you, 're)          34
# (thanks, so, much)      34
# (i, 'd, like)           34
# (out, of, town)         34
# (!, i, 'm)              33
# (what, is, your)        33
# (if, you, want)         33
# (up, a, time)           33
# (do, n't, have)         32
# (come, out, and)        32
# (can, call, me)         32
# (yes, ,, i)             32
# (to, come, by)          32
# (to, make, sure)        32
# (i, will, call)         32
# (in, the, afternoon)    32
# (i, can, get)           32
# (able, to, come)        32
# (let, us, know)         32
# (,, would, you)         32
# (i, wanted, to)         31
# (a, time, to)           31
# (a, look, at)           31
# (we, can, schedule)     31
# (me, your, address)     31
# (?, yes, i)             31
# (,, and, i)             31
# (,, if, you)            31
# (thanks, for, your)     30
# (., i, just)            30
# (you, have, time)       30
# (if, you, 'd)           30
# (?, i, will)            30
# (i, can, meet)          30
# (works, for, me)        30
# (forward, to, hearing)  30
# (,, we, can)            30
# ============================================================

# %%
# TO DO: Tina to investigate more word/phrases here. Put everything you tried in here.
# TO DO: add month, date, time pattern (e.g. "digit am" etc)

schedule_keywords = \
["book", "appointment","schedule","what time",'available', 'availability',\
 'works for you','morning','afternoon','evening', 'tomorrow', 'next week',\
 'monday','tuesday','wednesday','thursday','friday','saturday','sunday','weekday','weekend',\
 'me know when','a call', 'give you a', 'works for you', 'work for you', 'forward to hearing',\
 'today',' am ', ' pm ', 'can you make',\
 's your next availability', 'when i can call you', \
 'are you available on my date', 'when can i give you a call', ' give you a call', \
 'see you at', 'would like to book', 'book you']

# %%
scheduling_terms = pd.DataFrame(columns=('Term', 'Precision', 'Recall', 'Count'))
for i, term in enumerate(schedule_keywords):
    scheduling_terms.loc[i] = display_info(term, 'is_scheduling')
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in long_scalars

# %%
scheduling_terms.sort_values(by=['Precision', 'Recall'], ascending=False)
# Out:
#                             Term Precision Recall Count
# 32  when i can call you           nan%      0%     0
# 33  are you available on my date  nan%      0%     0
# 5   availability                  98%       2%     127
# 34  when can i give you a call    98%       1%     43
# 19  weekday                       97%       1%     28
# 3   what time                     96%       4%     211
# 29   pm                           95%       2%     88
# 13  tuesday                       93%       4%     186
# 14  wednesday                     91%       3%     165
# 4   available                     91%       13%    671
# 16  friday                        90%       7%     353
# 12  monday                        90%       6%     302
# 15  thursday                      90%       4%     226
# 6   works for you                 89%       2%     106
# 24  works for you                 89%       2%     106
# 2   schedule                      89%       10%    533
# 11  next week                     88%       3%     155
# 35   give you a call              88%       2%     101
# 25  work for you                  87%       3%     143
# 18  sunday                        87%       2%     123
# 17  saturday                      84%       5%     258
# 10  tomorrow                      84%       16%    817
# 8   afternoon                     83%       5%     254
# 9   evening                       81%       4%     190
# 30  can you make                  80%       0%     4
# 1   appointment                   79%       3%     179
# 37  would like to book            78%       0%     7
# 20  weekend                       76%       3%     173
# 27  today                         75%       9%     442
# 7   morning                       74%       9%     481
# 21  me know when                  74%       1%     52
# 22  a call                        68%       4%     220
# 23  give you a                    64%       3%     162
# 36  see you at                    64%       1%     27
# 38  book you                      56%       0%     15
# 0   book                          53%       4%     187
# 28   am                           53%       10%    517
# 26  forward to hearing            32%       1%     30
# 31  s your next availability      100%      0%     7

# %%
# TO DO: Tina to finalize the set of words to use by picking from the scheduling_terms list

scheduling_regex_words = ['availability','available','weekday','what time', 'weekday',\
                          'work for you','works for you', 'schedul','tomorrow','afternoon',\
                         'monday','tuesday','wednesday','thursday','friday','saturday','sunday',\
                         'can you make','when can i give you a call']

# %%
display_info_multiple(scheduling_regex_words, 'is_scheduling')
# Out:
# ['^.*(availability|available|weekday|what time|weekday|work for you|works for you|schedul|tomorrow|afternoon|monday|tuesday|wednesday|thursday|friday|saturday|sunday|can you make|when can i give you a call).*$',
#  '85%',
#  '59%',
#  3065]

# %%
# Example of further investigation
# the left over cases, i.e. 1 - recall cases
pat1 = '^.*(availability|available|weekday|what time|weekday|work for you|works for you|schedul|tomorrow|afternoon|monday|tuesday|wednesday|thursday|friday|saturday|sunday|can you make|when can i give you a call).*$'
df[(df.is_scheduling == 1) & (~df['message'].str.lower().str.match(pat1))].message.head(100)
# Out:
# 0      Greetings..\nAre you available for resume writing?
# 3      April. Can likely do est this wk & Work maybe the next. let me know your phone # & address.  Tx. Wade
# 5      Hey can you do the cleaning today at 937 court street reading pennsylvania
# 8      Yes one time  at 11am
# 13     Okay see you at 11:30 yes cash is fine
# 14     Ok thank you
# 31     Ok great! Having a back yard birthday party
# 32     Oh nice, let me know and I will make arrangements. Send me details, music requests, time to be there and address etc djtexasoutlaw@gmail.com 713-829-3708 and 281-691-0635
# 38     Hello Mr Simpson. This is Candace with Titans Pest Management. All of our technicians are on vacation out of the country this week. They will be resuming service on the 31st of July. I will be glad to put you on Todd's schedule for that Monday July 31st.\n\n- Candace M.
# 40     Hi Candace/Todd,\n\nCan someone please call me? Your phone number does not have voicemail and I would like to schedule service again. We are supposed to be on your bimonthly plan. \n\nThanks,\nChristopher Simpson \n850 686 3564
# 42     I need someone today
# 48     Good morning Anicka yes on both your question. Give me a call 617-699-8257 i have opening today if your to get started.
# 50     I was thinking of starting in two weeks if that is ok with you. how long are the sessions? Do i go to your gym or do you come to mine? How do i go about paying?
# 51     These are all good question that you are asking Anicka this is why the assessment is important. I will weigh you and take your body fat and talk about the direction we should go with your training. Also ask me any thing in person you need to know about location payment all that. How does that sound.
# 52     Anicka do you have transpation if so i would like to meet with you at Dunkin Doughnut or Panara Bread witch ever is better for you.
# 54     I want to make this very smooth for you so just give me a day an time that works fir you this week and i can make it happen ok Anicka.
# 57     yea that works. which one?
# 58     Lets do the Panara Bread at the South Bay Plaza 10am alright.
# 62     Sure that is not a problem Would you like to meet at the same place the Panera Bread in the South plaza ?
# 76     After 4:00
# 77     How about 4:15? May I have the best number to reach you at?
# 78     Hello Liz, I was wondering if you found someone to clean your house yet? I have 2 openings at the moment, if your interested please feel free to call me. I can also do a walk through and give you a free estimate. if you go to my profile it will tell you all about myself and what my clients have to say about me as well. 574-220-4261\nThank You, Amy James
# 81     Hello Liz, I called your son a couple days ago and left him a message and my phone number. I haven't heard anything back. When is the best time to call him?\nThank You, Amy James
# 82     Hi Amy.   I am on vacation this week but I will get back to you shortly.   Thanks for your patience.\nLiz
# 84     Amy,  Bill would like to have a trial run at cleaning his apartment. He lives at 5401 Sterling Drive Apt 3 Granger, IN which is the Main Street Village Apt complex.  Would you have availability to do the cleaning this Thursday afternoon, anytime Friday, or anytime next Monday or next Tuesday before 10 am.  He can be reached at 952-393-5162 but he has limited time to answer his phone so don't hesitate to call me at 484-515-6419 if you are having problems contacting him.  \n\nThanks,\nLiz McCool
# 89     Hi Isabella, may I ask what date are you planning your event for and can I have your email address to send the information your requesting?
# 90     Oct 29th and my email is isabella.fairchild@gmail.com
# 91     HI again, thanks for getting back to me so quickly. Unfortunately  the rest of Oct and Nov, we are fully booked already, that's why I wanted to confirm the date. I wish you luck with finding someone to cater your special event, let me know if you need any help.
# 99     Thank you so much! I will get the eyelash extensions and will pay the travel fee since no one will be able to take me during the day And my event starts at 4. Thank you so much for the help! I think I already booked you for the 19 on your website earlier today. I can just pay the additional charges in person. So in total, how much would I owe you with the traveling fee and eyelashes?
# 111    At Noah, the date and time would work for us. How long approximately will it take ? I live in a two bedroom high rise condo in downtown Atlanta, approximately 2000 square feet. address is 45 Ivan Allen Jr Blvd NW unit 2604 Atlanta GA
# 117    It's For A Graduation. They Gave Me A Notice That I Had To Come Earlier Then The Event. 7am Would Be Perfect
# 122    Good morning Sheila,\n\nI was recently notified by Thumbtack that you hired me for you're surprise 50th Birthday party.\n\nFirst off, Thank you so much for hiring me I assure you everyone will have a terrific time especially the Birthday boy!\n\nFeel free to contact me anytime that is convenient to go over the details of the party.\n\nI plan on reaching out to you later on Today to connect, answer any questions and get venue details.\n\nI look forward to speaking with you soon Sheila.\n\nBest regards,\n\nDJ Rob\nNext Event Services
# 123    Good afternoon Sheila,\r\n\r\nThank you very much for hiring me for your upcoming Surprise Birthday party June16th.\r\n\r\nI just called you and left a message with my contact info.\r\n\r\nAs this is a surprise Birthday party, feel free to contact me when it is most convenient anytime this weekend forward.\r\n\r\nI look forward to speaking with you Sheila.\r\n\r\nThank you,\r\n\r\nDJ Rob\r\nNext Event Services\r\nrobditalia@gmail.com\r\n(508) 951-4603
# 124    Good afternoon Sheila,\n\nThank you very much for hiring me for your upcoming Surprise Birthday party June16th.\n\nI just called you and left a message with my contact info.\n\nWhen you get a chance email me or call me to discuss the details of the party, answer any questions and to solidify the date.\n\nMy contact info is listed below and I look forward to speaking with you Sheila.\n\nThank you,\n\nDJ Rob\nNext Event Services\nrobditalia@gmail.com\n(508) 951-4603
# 125    Hello Rob, \nI received your voice mail I am currently working if I can give you a call later this afternoon to discuss more for the party. \nThanks!
# 126    Hello Sheila,\n\nGreat to hear from you, no worries just give me a call when you are free and it is a convenient time to speak.\n\nThank you,\n\nRob\nNext Event Services\n(508) 951-4603
# 128    Hello Sheila,\n\nWhen you get a chance could you please confirm you received the professional disc jockey agreement that I sent out to you this past Friday.\n\nAlso while I have you how should I dress for the party - Casual, semi formal or formal?\n\nI look forward to meeting you, Heather and John this Friday.\n\nThank you,\n\nDJ Rob\nNext Event Services
# 130    Hello Heather,\n\nNo worries about printing the DJ contract out.  I can have a second copy on me on Friday when we meet.\n\nIf you would like a copy before hand send me your email address and I can send it out right away to you.\n\nI look forward to meeting you, Sheila and John on Friday and ensuring everyone has a great time with the dance music!\n\nThank you,\n\nDJ Rob\nNext Event Services
# 136    I get off work at 7pm Eastern Time. Is that too late for you?
# 137    I think that will work. I’ll be driving back from a 3 hour trip. If I’m not going to make it, I’ll let you know. Call me at 4083761398.
# 145    Sure, is 1:00 ok? The home is only a few years old so it's not so cluttered or anything .. eeborneman@aol.com.. could I just give you a quick call too?
# 149    Hi Bill,\nI wrote you back, but it appears my message disappeared! So strange. We would love to have you come out and take a look at our trees and give us an estimate. I'm free most Saturdays and Sunday's . If you're not free on weekends we can work out a weekday depending on my girlfriends day off. Let me know! \nThanks!\nWhitney
# 153    Tom,\nNo worries with what we use the baits and or sprays have no odor or fumes , we would keep any product placement out of harms way for your pet. The soonest appointment available is Monday? Afternoon if that works.  1 to 3 or 3 to 5 pm
# 155    Monday works great, if we can shoot for 1-3. Do you take cash, credit, check?\n\nThanks
# 168    Would you be able to do this today?
# 171    Yessir. Please send address
# 206    Hi Faith..yes feel free to contact me at 404.966.8963
# 207    Hi Daphne, thanks again for listening! :) \nTo confirm: We are looking for standard crab boil:\nBlue crabs, shrimp, potatoes, corn, sausage. etc.\nDo you serve a sauce with yours?\nWe like to do this live...big pot, in the backyard area etc.\n\nAppetizers: Would love to do the hushpuppies, and some light refreshing apps. I usually do, deviled eggs, rainbow fruit skewers. etc. \n\nI will handle dessert. \n\nLet me know if there is anything else you need from me so we can lock down Saturday, June 24th. \n\nDo you have any pictures of your crab boils? I don't think I saw any on the website.\n\nThanks so much!\n\nFaith
# 216    Hi Faith...Hope you're well:)\n\nI'm circling back around with you on the June 24th Crab Boil, last communication you were going to make a decision after discussing with your husband.  Did you two decide on the direction you are going in?\n\nThank You,\nDaphne
# 227    Hi Martin, sorry it took so long to get back to you! Would you be open to doing sessions with my fiance and I in our apartment gym in Bronxville? We would ideally do one session a week, around 6:30/7am during the work week. Please let me know what you think, and what something like that might cost. Thanks!!!
# 228    Hi Chelsea,\nYes, I would love to design a program for you and your husband.\n\nLet's schedule a brief phone consultation to further discuss the program.\n\nDo you have time this evening? Should take about 15-30 minutes.
# 231    Okay. I don't get home until 6:30, would that be an issue for someone to come so late?
# 249    Yes, just the metal coping.  Building is at 611 Magnolia Street NW, Atlanta GA 30314.  Location is few blocks west of the Georgia Dome.  Let me know when you're going so I can answer the inevitable calls from neighbors that know no one should be up there.
# 256    Hi Steve,\n\nI am so sorry for the delay. We have been slacking on planning. We would like to hire you. Are you still available?\n\nThanks,\nMeghan
# 274    Thank you for your prompt response. What kind of time frame? And are you insured?
# 290    I have a couple questions when could we talk on the phone ?
# ...
# 397    Hi Bojidar,\n\nHow is the event planning going? Many people like to wait until they find the perfect menu to book for catering. I think you may find our new Street Taco Fiesta menu to be surprising perfect for your meal. It is even available to be served from our food truck!\n\nFor a limited time, you can save 25% with our Introductory Special Offer. Check out the menu here: http://artisanfoodworkscatering.blogspot.com/2017/05/street-taco-fiesta.html. \n\nWhile Artisan Foodworks is currently still open for your event, availability may change without notice if someone else buys the date of service. We may also available for the day before and the day after. Perfect for rehearsal dinners and casual meals. \n\nPlease reply to this email to set up a complimentary consultation. I'm also available to chat at 812.372.9898.\n\nThank you,\nSam
# 406    Okay, Great like to complete in one shot waiting on time availaibilty frommy tenant and will keep you posted
# 412    Thanks Dave will reach out for follow-up treatment in 3-4 weeks , I believe would u suggest. Would that be for rodent/roaches or just rodent and how much would the followup treatment cost.  Thanks.
# 419    Ok I can come out between 9 and 11am and provide a quote. What is your address?
# 420    Can you narrow the time?
# 421    Ok how about between 10 and 1030?
# 434    Good Morning,\n\nIs there a good time to schedule a call?\n\nJames,
# 435    Good Monday Morning,\n\nIs there a  good time to schedule a call this week?\n\nJames,
# 441    Good Morning Vaneta,\n\nHow was your weekend? Is there a good time to chat regarding the photography and videography project?\n\nJames,
# 443    Hi Vaneta,\n\nIs there a good time to schedule a chat?\n\nJames,
# 444    Good Morning Vaneta,\n\nHow was your weekend? Is there a good time to schedule a chat?\n\nJames,
# 445    Good Morning Vaneta,\n\nHow was your Memorial Day weekend?\n\nIs there a good time to schedule a call regarding your wedding day services?\n\nJames,
# 446    Good Morning,\n\nIs there a good time to chat regarding your request?\n\nJames,
# 447    Good Monday Morning,\n\nHow was your weekend? Do you have any questions or concerns? \n\nIs there a good time to schedule a chat?\n\nJames,
# 449    Good Morning,\n\nIs there a good time to chat regarding your request this week?\n\nJames,
# 450    Happy Friday Vaneta,\n\nDo you have questions or concerns? We look forward to speaking with you regarding your wedding in August.\n\nCheers,
# 452    Happy Tuesday,\n\nIs there a good time to chat regarding your request?\n\nJames,
# 453    Good Afternoon Vaneta,\n\nHow was your weekend? Is there a good time to schedule a date to speak regarding your wedding?\n\nJames,
# Name: message, dtype: object

# %%
## Example of further investigations
## investigate the regex related to word "book"
pat1 = re.compile('^.*(book).*$' , flags = re.DOTALL) # equivalent to str.contains
pat2 = re.compile('^.*(availability|available|weekday|what time|weekday|work for you|works for you|schedul|tomorrow|afternoonmonday|tuesday|wednesday|thursday|friday|saturday|sunday).*$' , flags = re.DOTALL) # equivalent to str.contains

# df[(df.is_scheduling == 1) & (df['message'].str.lower().str.match(pat1))\
#   & (~df['message'].str.lower().str.match(pat2))].message.head(100)

get_info(df[(df.is_scheduling == 1) & (df['message'].str.lower().str.match(pat1))\
   & (~df['message'].str.lower().str.match(pat2))].message.str.lower().str.cat(sep=' '))
# Out:
# Unigram frequencies:
#                Frequency
# Word
# i              90
# the            85
# you            85
# to             75
# for            42
# and            40
# your           32
# book           32
# is             29
# a              28
# we             25
# booked         24
# if             24
# so             23
# in             22
# do             22
# me             21
# as             20
# on             19
# that           18
# my             18
# be             17
# would          17
# it             17
# have           17
# $              17
# will           16
# can            16
# are            15
# let            15
# at             14
# need           13
# thank          13
# 'm             13
# date           12
# with           12
# this           12
# about          12
# hi             11
# know           11
# booking        11
# of             10
# day            10
# out            10
# like           10
# thanks         9
# just           9
# or             9
# am             9
# up             9
# time           8
# -              8
# what           8
# sorry          7
# could          7
# please         7
# help           6
# much           6
# get            6
# today          6
# how            6
# there          6
# other          6
# but            6
# they           6
# call           6
# already        5
# want           5
# forward        5
# n't            5
# weekend        5
# not            5
# now            5
# also           5
# 've            5
# open           5
# talk           5
# july           5
# us             5
# good           5
# moving         5
# give           5
# back           4
# any            4
# travel         4
# no             4
# think          4
# makeup         4
# appointment    4
# going          4
# two            4
# soon           4
# here           4
# girls          4
# still          4
# morning        4
# come           4
# quote          4
# go             4
# possible       4
# our            4
# meeting        4
# week           4
# quickly        3
# unfortunately  3
# wanted         3
# event          3
# fee            3
# one            3
# able           3
# take           3
# total          3
# works          3
# hair           3
# contract       3
# looking        3
# wedding        3
# deposit        3
# well           3
# 60             3
# everything     3
# hope           3
# some           3
# love           3
# next           3
# got            3
# from           3
# free           3
# provide        3
# far            3
# ahead          3
# price          3
# trial          3
# see            3
# face           3
# 'll            3
# phone          3
# job            3
# anything       3
# charge         3
# move           3
# lesson         3
# hear           3
# send           3
# email          3
# number         3
# more           3
# yes            3
# ill            3
# information    3
# down           3
# he             3
# getting        2
# rest           2
# confirm        2
# pay            2
# 19             2
# website        2
# earlier        2
# additional     2
# found          2
# request        2
# okay           2
# 2pm            2
# may            2
# 11th           2
# confirmed      2
# another        2
# massage        2
# bride          2
# until          2
# was            2
# working        2
# same           2
# all            2
# once           2
# mark           2
# min            2
# pm             2
# else           2
# did            2
# both           2
# maids          2
# honor          2
# 100            2
# plan           2
# too            2
# house          2
# fairly         2
# small          2
# bring          2
# etc            2
# way            2
# exactly        2
# ideas          2
# their          2
# client         2
# evening        2
# own            2
# stuff          2
# ============================================================
# Bigram frequencies:
#                      Frequency
# Word
# (., i)               18
# (to, book)           17
# (i, 'm)              13
# (,, i)               13
# (thank, you)         12
# (in, the)            10
# (if, you)            9
# (let, me)            8
# (me, know)           8
# (!, i)               8
# (you, for)           8
# (on, the)            8
# (like, to)           8
# (i, will)            7
# (for, the)           7
# (i, am)              7
# (need, to)           7
# (the, date)          6
# (know, if)           6
# (., thank)           6
# (i, have)            6
# (i, do)              6
# (., we)              6
# (book, the)          6
# (we, are)            5
# (i, can)             5
# (book, your)         5
# (you, !)             5
# (as, i)              5
# (., the)             5
# (booked, .)          5
# (is, the)            5
# (for, your)          5
# (i, 've)             5
# (you, have)          5
# (would, like)        5
# (i, would)           5
# (you, need)          4
# (the, day)           4
# (already, booked)    4
# (on, your)           4
# (., so)              4
# (., let)             4
# (?, hi)              4
# (soon, as)           4
# (), .)               4
# (for, $)             4
# (a, call)            4
# (i, need)            4
# (,, and)             4
# (to, you)            4
# (., would)           4
# (would, you)         4
# (?, i)               4
# (would, be)          4
# (back, to)           3
# (quickly, .)         3
# (,, we)              3
# (you, so)            3
# (so, much)           3
# (will, get)          3
# (will, be)           3
# (be, able)           3
# (able, to)           3
# (today, .)           3
# (and, your)          3
# (you, do)            3
# (booked, for)        3
# (,, as)              3
# (contract, .)        3
# (so, sorry)          3
# (and, i)             3
# (,, but)             3
# (booked, in)         3
# (as, well)           3
# (is, booked)         3
# (want, to)           3
# (what, i)            3
# (what, is)           3
# (,, thank)           3
# ('ve, got)           3
# ('m, booked)         3
# (as, soon)           3
# (you, know)          3
# (is, $)              3
# (a, trial)           3
# (the, morning)       3
# (we, can)            3
# (to, come)           3
# (book, you)          3
# (do, you)            3
# (we, do)             3
# (do, n't)            3
# (you, like)          3
# (are, you)           3
# (please, let)        3
# (if, i)              3
# (you, a)             3
# (me, a)              3
# (you, .)             3
# (give, you)          3
# (., you)             3
# (forward, to)        3
# (you, are)           3
# (to, be)             3
# (!, !)               3
# (,, thanks)          2
# (thanks, for)        2
# (for, getting)       2
# (getting, back)      2
# (to, me)             2
# (., unfortunately)   2
# (the, rest)          2
# (rest, of)           2
# (,, that)            2
# (that, 's)           2
# (wanted, to)         2
# (to, confirm)        2
# (date, .)            2
# (,, let)             2
# (help, .)            2
# (pay, the)           2
# (travel, fee)        2
# (to, take)           2
# (much, for)          2
# (i, think)           2
# (your, website)      2
# (in, total)          2
# (total, ,)           2
# (with, the)          2
# (just, found)        2
# (the, booking)       2
# (booking, request)   2
# (if, that)           2
# (2pm, on)            2
# (makeup, ,)          2
# (your, appointment)  2
# (going, to)          2
# (is, there)          2
# (date, and)          2
# (,, you)             2
# (your, massage)      2
# (could, you)         2
# (do, your)           2
# (that, time)         2
# (that, i)            2
# (,, this)            2
# ('m, so)             2
# (sorry, .)           2
# (the, other)         2
# (other, bride)       2
# (about, it)          2
# (looking, forward)   2
# (with, you)          2
# (but, i)             2
# (day, as)            2
# (., once)            2
# (well, .)            2
# (-, i)               2
# (to, my)             2
# (the, weekend)       2
# (book, for)          2
# ($, 100)             2
# (!, ))               2
# (but, if)            2
# (could, be)          2
# (the, house)         2
# (they, will)         2
# (you, to)            2
# (etc, .)             2
# (that, is)           2
# (?, also)            2
# (for, a)             2
# (do, i)              2
# (to, provide)        2
# (my, own)            2
# (how, far)           2
# (a, little)          2
# (book, up)           2
# (,, it)              2
# ($, 50)              2
# (50, for)            2
# (depending, on)      2
# (book, a)            2
# (trial, for)         2
# (talk, to)           2
# (., just)            2
# (just, to)           2
# (let, you)           2
# (are, booked)        2
# (me, to)             2
# (you, can)           2
# (., sounds)          2
# (sounds, good)       2
# (&, quote)           2
# (quote, and)         2
# (and, the)           2
# (to, go)             2
# (go, ahead)          2
# (ahead, and)         2
# ============================================================
# Trigram frequencies:
#                              Frequency
# Word
# (let, me, know)              8
# (., thank, you)              6
# (like, to, book)             6
# (me, know, if)               5
# (would, like, to)            5
# (thank, you, for)            4
# (i, need, to)                4
# (know, if, you)              3
# (thank, you, so)             3
# (you, so, much)              3
# (be, able, to)               3
# (thank, you, !)              3
# (,, i, 'm)                   3
# (., i, have)                 3
# (what, is, the)              3
# (i, 've, got)                3
# (i, 'm, booked)              3
# (as, soon, as)               3
# (in, the, morning)           3
# (., would, you)              3
# (would, you, like)           3
# (please, let, me)            3
# (to, book, the)              3
# (i, would, like)             3
# (,, thanks, for)             2
# (for, getting, back)         2
# (getting, back, to)          2
# (the, rest, of)              2
# (,, let, me)                 2
# (if, you, need)              2
# (i, will, get)               2
# (you, for, the)              2
# (on, your, website)          2
# (in, total, ,)               2
# (., let, me)                 2
# (to, book, your)             2
# (,, i, am)                   2
# (,, as, i)                   2
# (i, 'm, so)                  2
# (so, sorry, .)               2
# (the, other, bride)          2
# (as, well, .)                2
# (is, booked, .)              2
# (to, book, for)              2
# (for, $, 100)                2
# (,, thank, you)              2
# (you, for, your)             2
# (., i, 've)                  2
# (do, i, need)                2
# ($, 50, for)                 2
# (to, book, a)                2
# (a, trial, for)              2
# (let, you, know)             2
# (., we, are)                 2
# (., i, do)                   2
# (., sounds, good)            2
# (!, i, am)                   2
# (to, go, ahead)              2
# (go, ahead, and)             2
# (ahead, and, book)           2
# (book, you, for)             2
# (soon, as, possible)         2
# (do, n't, charge)            2
# (you, like, to)              2
# (?, i, 'm)                   2
# (., please, let)             2
# (know, if, i)                2
# (,, and, i)                  2
# (give, me, a)                2
# (me, a, call)                2
# (a, call, at)                2
# (we, can, talk)              2
# (from, you, .)               2
# (to, give, you)              2
# (i, am, booked)              2
# (set, up, a)                 2
# (booked, in, the)            2
# (!, i, can)                  2
# (i, can, offer)              2
# (,, i, would)                2
# (our, contract, .)           2
# (., i, would)                2
# (look, forward, to)          2
# (the, down, payment)         2
# (booked, ., i)               2
# (if, you, have)              2
# (you, have, any)             2
# (we, need, to)               2
# (me, know, what)             2
# (on, july, 20th)             2
# (., luiz, truck)             2
# (luiz, truck, easy)          2
# (hi, again, ,)               1
# (again, ,, thanks)           1
# (thanks, for, getting)       1
# (back, to, me)               1
# (to, me, so)                 1
# (me, so, quickly)            1
# (so, quickly, .)             1
# (quickly, ., unfortunately)  1
# (., unfortunately, the)      1
# (unfortunately, the, rest)   1
# (rest, of, oct)              1
# (of, oct, and)               1
# (oct, and, nov)              1
# (and, nov, ,)                1
# (nov, ,, we)                 1
# (,, we, are)                 1
# (we, are, fully)             1
# (are, fully, booked)         1
# (fully, booked, already)     1
# (booked, already, ,)         1
# (already, ,, that)           1
# (,, that, 's)                1
# (that, 's, why)              1
# ('s, why, i)                 1
# (why, i, wanted)             1
# (i, wanted, to)              1
# (wanted, to, confirm)        1
# (to, confirm, the)           1
# (confirm, the, date)         1
# (the, date, .)               1
# (date, ., i)                 1
# (., i, wish)                 1
# (i, wish, you)               1
# (wish, you, luck)            1
# (you, luck, with)            1
# (luck, with, finding)        1
# (with, finding, someone)     1
# (finding, someone, to)       1
# (someone, to, cater)         1
# (to, cater, your)            1
# (cater, your, special)       1
# (your, special, event)       1
# (special, event, ,)          1
# (event, ,, let)              1
# (you, need, any)             1
# (need, any, help)            1
# (any, help, .)               1
# (help, ., thank)             1
# (so, much, !)                1
# (much, !, i)                 1
# (!, i, will)                 1
# (will, get, the)             1
# (get, the, eyelash)          1
# (the, eyelash, extensions)   1
# (eyelash, extensions, and)   1
# (extensions, and, will)      1
# (and, will, pay)             1
# (will, pay, the)             1
# (pay, the, travel)           1
# (the, travel, fee)           1
# (travel, fee, since)         1
# (fee, since, no)             1
# (since, no, one)             1
# (no, one, will)              1
# (one, will, be)              1
# (will, be, able)             1
# (able, to, take)             1
# (to, take, me)               1
# (take, me, during)           1
# (me, during, the)            1
# (during, the, day)           1
# (the, day, and)              1
# (day, and, my)               1
# (and, my, event)             1
# (my, event, starts)          1
# (event, starts, at)          1
# (starts, at, 4.)             1
# (at, 4., thank)              1
# (4., thank, you)             1
# (so, much, for)              1
# (much, for, the)             1
# (for, the, help)             1
# (the, help, !)               1
# (help, !, i)                 1
# (!, i, think)                1
# (i, think, i)                1
# (think, i, already)          1
# (i, already, booked)         1
# (already, booked, you)       1
# (booked, you, for)           1
# (for, the, 19)               1
# (the, 19, on)                1
# (19, on, your)               1
# (your, website, earlier)     1
# (website, earlier, today)    1
# (earlier, today, .)          1
# (today, ., i)                1
# (., i, can)                  1
# (i, can, just)               1
# (can, just, pay)             1
# (just, pay, the)             1
# (pay, the, additional)       1
# (the, additional, charges)   1
# (additional, charges, in)    1
# (charges, in, person)        1
# (in, person, .)              1
# (person, ., so)              1
# (., so, in)                  1
# ============================================================

# %% [markdown]
# ## Payment

# %%
df[(df.is_payment==1) & (df.is_generic == 1)].shape
# Out:
# (8, 18)

# %%
df[(df.is_payment==1)].shape
# Out:
# (437, 18)

# %%
get_info(df[df.is_payment == 1].message.str.lower().str.cat(sep=' '))
# Out:
# Unigram frequencies:
#            Frequency
# Word
# the        758
# you        753
# i          726
# to         626
# and        490
# a          340
# for        328
# is         248
# can        246
# your       232
# we         231
# of         228
# do         222
# will       219
# that       201
# be         198
# in         187
# me         187
# have       184
# it         178
# if         172
# or         169
# on         154
# my         148
# with       144
# would      131
# check      117
# so         116
# payment    113
# at         113
# as         112
# send       106
# deposit    99
# cash       96
# $          91
# pay        90
# are        86
# get        86
# need       81
# like       79
# this       78
# know       76
# work       73
# also       71
# thanks     70
# please     69
# n't        69
# what       69
# all        68
# just       65
# not        65
# up         65
# let        64
# email      64
# but        64
# when       64
# time       64
# there      60
# credit     57
# an         57
# am         56
# thank      55
# &          55
# take       54
# hi         53
# 'll        51
# out        50
# any        50
# contract   50
# address    48
# how        47
# -          47
# day        46
# yes        44
# our        44
# then       42
# make       42
# invoice    40
# card       39
# 'm         38
# from       38
# accept     37
# great      36
# could      36
# see        35
# much       35
# by         35
# well       35
# want       35
# about      34
# more       34
# one        33
# phone      33
# back       33
# after      33
# quote      32
# %          31
# call       31
# date       30
# paypal     30
# tomorrow   30
# number     29
# questions  29
# ok         28
# go         28
# no         28
# cards      28
# monday     27
# them       27
# only       26
# sure       25
# wedding    25
# service    25
# before     25
# was        24
# works      24
# which      24
# us         24
# best       24
# here       24
# they       24
# paid       24
# ...        24
# event      23
# 'd         23
# home       23
# some       23
# fine       22
# week       22
# done       22
# going      22
# 2          22
# full       22
# her        22
# come       21
# today      21
# over       21
# does       21
# services   21
# video      21
# sorry      21
# now        21
# good       21
# should     20
# free       20
# give       20
# meet       20
# photos     20
# mail       19
# once       19
# sent       19
# due        19
# price      19
# right      19
# use        19
# look       19
# may        19
# via        19
# available  18
# other      18
# way        18
# very       18
# info       18
# leave      18
# dog        18
# hey        17
# 3          17
# @          17
# 50         17
# where      17
# charge     17
# weeks      16
# paying     16
# help       16
# forward    16
# first      16
# set        16
# something  16
# feel       16
# payments   16
# next       16
# she        16
# days       16
# session    16
# him        16
# two        15
# able       15
# did        15
# put        15
# move       15
# looking    15
# provide    15
# complete   15
# sign       15
# paint      15
# job        15
# 're        15
# hello      15
# still      15
# text       15
# ============================================================
# Bigram frequencies:
#                   Frequency
# Word
# (., i)            195
# (if, you)         94
# (i, will)         86
# (,, i)            75
# (i, can)          71
# (will, be)        65
# (do, you)         57
# (of, the)         56
# (you, can)        55
# (thank, you)      54
# (for, the)        54
# (let, me)         50
# (we, can)         48
# (i, am)           48
# (in, the)         47
# (i, have)         46
# (me, know)        46
# (,, and)          46
# (!, i)            42
# (on, the)         41
# (i, 'll)          41
# (you, have)       41
# (., the)          41
# (for, you)        41
# (have, a)         40
# (and, i)          39
# (., thanks)       38
# (a, check)        38
# (i, 'm)           38
# (do, n't)         38
# (like, to)        36
# (., if)           34
# (?, i)            34
# (to, be)          33
# (would, be)       32
# (., we)           32
# (would, like)     32
# (send, you)       32
# (you, .)          31
# (i, would)        31
# (i, do)           31
# (the, deposit)    30
# (the, contract)   29
# (to, you)         28
# (as, well)        28
# (you, a)          27
# (., you)          27
# (to, get)         26
# (it, 's)          26
# (,, we)           26
# (you, would)      26
# (with, the)       25
# (at, the)         25
# (credit, card)    24
# (., my)           24
# (can, you)        24
# (and, the)        24
# (:, ))            24
# (you, are)        24
# (to, the)         23
# (have, to)        22
# (to, do)          22
# (we, will)        22
# (that, 's)        22
# (to, pay)         22
# (., please)       22
# (we, are)         22
# (send, me)        21
# (,, but)          21
# (., thank)        20
# (the, check)      20
# (but, i)          20
# (a, deposit)      20
# (credit, cards)   20
# (for, your)       20
# (,, or)           20
# (!, !)            20
# (and, we)         20
# (do, i)           19
# (the, day)        19
# (you, for)        19
# (you, to)         19
# (of, your)        19
# (be, there)       19
# (you, the)        19
# (check, or)       18
# (when, you)       18
# (for, a)          18
# (can, be)         18
# (,, so)           18
# (so, i)           18
# (., do)           18
# (need, to)        18
# (you, want)       18
# (know, if)        18
# (want, to)        18
# (can, pay)        18
# (that, you)       17
# (., hi)           17
# (your, email)     17
# (you, !)          17
# (going, to)       17
# (have, any)       17
# (contract, and)   17
# (thanks, !)       16
# (cash, or)        16
# (that, i)         16
# (able, to)        15
# (cash, ,)         15
# (you, ,)          15
# (the, address)    15
# (to, my)          15
# (can, send)       15
# (., what)         15
# (., can)          15
# (and, then)       15
# (you, do)         15
# (email, address)  15
# (,, you)          15
# (also, ,)         15
# (you, take)       14
# (see, you)        14
# (me, to)          14
# (for, me)         14
# (check, .)        14
# (you, need)       14
# (to, send)        14
# (i, pay)          14
# (is, the)         14
# (you, ?)          14
# (you, send)       14
# (when, we)        14
# (), .)            14
# (., -)            14
# (pay, you)        14
# (i, was)          13
# (how, do)         13
# (so, much)        13
# (we, do)          13
# (will, need)      13
# (phone, number)   13
# (i, 'd)           13
# (forward, to)     13
# (please, let)     13
# (yes, ,)          13
# (any, questions)  13
# (day, of)         13
# (to, have)        13
# (., also)         13
# (cash, .)         13
# (the, date)       13
# (., let)          13
# (i, just)         13
# (i, get)          13
# (is, fine)        12
# (with, you)       12
# (i, also)         12
# (50, %)           12
# (., it)           12
# (&, quote)        12
# (?, yes)          12
# (you, accept)     12
# ('d, like)        12
# (i, need)         12
# (of, payment)     12
# (deposit, is)     12
# (can, i)          12
# (me, .)           12
# (,, the)          12
# (well, .)         12
# (cash, is)        11
# (that, is)        11
# (all, the)        11
# (work, .)         11
# (you, on)         11
# (are, you)        11
# (and, send)       11
# (or, cash)        11
# (or, credit)      11
# (,, it)           11
# (and, your)       11
# (know, .)         11
# (over, the)       11
# (will, you)       11
# (free, to)        11
# (will, send)      11
# (that, we)        11
# (,, which)        11
# (is, a)           11
# (be, paid)        11
# (an, invoice)     11
# (we, have)        11
# (to, make)        11
# (you, get)        11
# (can, get)        11
# (deposit, to)     11
# (please, send)    11
# (you, 're)        11
# (there, is)       11
# (if, that)        10
# ============================================================
# Trigram frequencies:
#                          Frequency
# Word
# (let, me, know)          46
# (., if, you)             23
# (., i, will)             22
# (., thank, you)          20
# (you, would, like)       19
# (would, like, to)        19
# (if, you, have)          18
# (you, have, any)         16
# (., i, am)               16
# (., i, can)              15
# (., i, have)             15
# (i, do, n't)             15
# (., do, you)             14
# (., i, do)               14
# (me, know, if)           14
# (do, you, take)          13
# (if, you, would)         13
# (., you, can)            13
# (know, if, you)          13
# (., let, me)             13
# (the, contract, and)     13
# (do, you, accept)        12
# (thank, you, for)        12
# (and, i, will)           12
# (., i, would)            11
# (please, let, me)        11
# (i, can, send)           11
# (for, you, .)            11
# (you, can, pay)          11
# (as, well, .)            11
# (send, you, a)           11
# (i, have, a)             10
# (., i, 'll)              10
# (you, do, n't)           10
# (have, any, questions)   10
# (just, let, me)          10
# (i, 'll, send)           10
# (., thanks, !)           9
# (,, thank, you)          9
# (me, know, .)            9
# (feel, free, to)         9
# (i, will, send)          9
# (i, would, like)         9
# (do, i, pay)             9
# (i, will, be)            9
# (and, we, can)           9
# (,, i, am)               9
# (,, i, 'll)              9
# (be, able, to)           8
# (i, will, need)          8
# (in, the, mail)          8
# (a, check, .)            8
# (check, or, cash)        8
# (,, we, can)             8
# (you, 'd, like)          8
# ('d, like, to)           8
# (i, 'll, be)             8
# (look, forward, to)      8
# (the, day, of)           8
# (if, you, are)           8
# (your, email, address)   8
# (,, you, can)            8
# (if, you, want)          8
# (., i, 'm)               8
# (for, you, ?)            8
# (the, end, of)           8
# (end, of, the)           8
# (thank, you, !)          8
# (please, send, me)       8
# (so, i, can)             8
# (how, do, i)             7
# (!, i, will)             7
# (?, i, can)              7
# (you, have, a)           7
# (will, send, you)        7
# (., i, also)             7
# (for, the, deposit)      7
# (can, send, you)         7
# (send, you, an)          7
# (thanks, so, much)       7
# (a, check, for)          7
# (you, ., i)              7
# (on, the, day)           7
# (it, would, be)          7
# (!, !, !)                7
# (you, want, to)          7
# (?, also, ,)             7
# (to, you, .)             7
# (accept, credit, cards)  7
# (at, the, end)           7
# (send, me, your)         7
# ('ll, send, you)         7
# (i, can, get)            7
# (do, you, have)          7
# (credit, cards, ?)       7
# (thank, you, so)         6
# (you, so, much)          6
# (let, you, know)         6
# (thank, you, ,)          6
# (what, is, your)         6
# (over, the, phone)       6
# (,, i, will)             6
# (going, to, be)          6
# (leave, a, check)        6
# (., can, you)            6
# (can, you, send)         6
# (you, send, me)          6
# (,, and, then)           6
# (i, look, forward)       6
# (any, questions, or)     6
# (can, be, paid)          6
# (cash, or, check)        6
# (,, if, you)             6
# (send, me, an)           6
# (if, you, do)            6
# (me, know, what)         6
# (,, and, i)              6
# (?, i, will)             6
# (how, do, you)           6
# (or, credit, card)       6
# (., thanks, .)           6
# (for, you, to)           6
# (send, you, the)         6
# (me, your, email)        6
# (., please, let)         6
# (i, will, get)           5
# (so, much, for)          5
# (need, your, address)    5
# (i, will, put)           5
# (i, can, do)             5
# (you, a, check)          5
# (do, you, need)          5
# (would, have, to)        5
# (looking, forward, to)   5
# (you, and, your)         5
# (would, you, like)       5
# (send, a, check)         5
# (credit, card, ?)        5
# (if, you, 'd)            5
# (and, i, can)            5
# (back, to, me)           5
# (50, %, deposit)         5
# (for, me, .)             5
# (,, but, i)              5
# (day, of, the)           5
# (,, i, 'm)               5
# (,, i, can)              5
# (like, to, book)         5
# (do, you, want)          5
# (be, there, .)           5
# (to, be, there)          5
# (have, to, be)           5
# (the, date, .)           5
# (as, far, as)            5
# (,, do, you)             5
# (you, accept, credit)    5
# (send, it, to)           5
# (deposit, to, hold)      5
# (will, be, due)          5
# (., please, send)        5
# (to, hold, the)          5
# (), ., i)                5
# (we, accept, cash)       5
# (accept, cash, ,)        5
# (credit, card, .)        5
# (and, i, 'll)            5
# (:, ), i)                5
# (you, an, invoice)       5
# (check, or, credit)      5
# (if, there, is)          5
# (me, ., i)               5
# (., :, ))                5
# (when, you, get)         5
# (do, n't, have)          5
# (and, you, can)          5
# (if, you, can)           5
# (that, will, be)         5
# (works, for, you)        5
# (., i, could)            5
# (will, be, there)        5
# (can, pay, you)          5
# (will, you, be)          5
# (., i, just)             5
# (forms, of, payment)     5
# (as, well, as)           5
# (you, take, cash)        4
# (with, you, .)           4
# (do, i, go)              4
# (or, do, you)            4
# (will, be, able)         4
# (will, need, the)        4
# (., are, you)            4
# (., but, i)              4
# (to, do, is)             4
# (a, deposit, ?)          4
# (?, do, you)             4
# (by, check, or)          4
# (i, 'm, not)             4
# (i, would, be)           4
# (it, 's, not)            4
# ============================================================

# %%
# TO DO: Tina to investigate more word/phrases here. Put everything you tried in here.
# Hint: use the investigation examples to get inspirations 

payment_keywords = \
["pay", "payment", "credit card", "cash", "check", "debit", "invoice", "payment", "deposit", "paypal", \
 "the deposit", "send you", "the contract", "a deposit", "the check", \
 "do you accept", "i will need", "you can pay", "will send you",\
 "send me your", "can send you", "a check", "check or cash",\
 "do i pay", "send you an", "send you the", "deposit to hold the",\
 "do you accept credit", "do you take cash", "check or credit card", "payment do you accept", \
 "at your earliest convenience", "hold the date", "send you an invoice"]

# %%
payment_terms = pd.DataFrame(columns=('Term', 'Precision', 'Recall', 'Count'))
for i, term in enumerate(payment_keywords):
    payment_terms.loc[i] = display_info(term, 'is_payment')

# %%
payment_terms.sort_values(by=['Precision', 'Recall'], ascending=False)
# Out:
#                             Term Precision Recall Count
# 2   credit card                   95%       10%    42
# 9   paypal                        91%       7%     31
# 14  the check                     91%       5%     20
# 23  do i pay                      90%       2%     9
# 21  a check                       89%       9%     41
# 3   cash                          87%       22%    97
# 10  the deposit                   85%       7%     29
# 1   payment                       82%       24%    104
# 7   payment                       82%       24%    104
# 8   deposit                       82%       21%    93
# 13  a deposit                     80%       5%     20
# 33  send you an invoice           80%       1%     4
# 6   invoice                       73%       10%    43
# 26  deposit to hold the           67%       1%     4
# 0   pay                           64%       47%    206
# 19  send me your                  6%        2%     7
# 32  hold the date                 56%       1%     5
# 24  send you an                   38%       1%     6
# 12  the contract                  37%       6%     25
# 4   check                         27%       28%    123
# 31  at your earliest convenience  27%       1%     3
# 20  can send you                  22%       2%     8
# 25  send you the                  19%       1%     6
# 16  i will need                   18%       2%     8
# 18  will send you                 18%       2%     7
# 11  send you                      16%       7%     29
# 15  do you accept                 100%      3%     12
# 17  you can pay                   100%      3%     11
# 22  check or cash                 100%      2%     8
# 5   debit                         100%      1%     6
# 27  do you accept credit          100%      1%     5
# 28  do you take cash              100%      1%     4
# 29  check or credit card          100%      1%     4
# 30  payment do you accept         100%      1%     4

# %%
# TO DO: Tina to finalize the set of words to use by picking from the payment_terms list

payment_regex_words = ['debit','credit card','the check','paypal', 'venmo',\
                          'the deposit', 'do i pay']

# %%
display_info_multiple(payment_regex_words, 'is_payment')
# Out:
# ['^.*(debit|credit card|the check|paypal|venmo|the deposit|do i pay).*$',
#  '92%',
#  '29%',
#  126]
